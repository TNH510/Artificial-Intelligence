# %% [markdown]
# <a href="https://colab.research.google.com/github/TNH510/Artificial-Intelligence/blob/main/New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model

# %%
model100 = load_model('/content/drive/MyDrive/AI/Week_10/cifar100.h5')

# %%
from keras.utils import load_img, img_to_array
from matplotlib import pyplot as plt
url = '/content/drive/MyDrive/AI/Week_10/voi.jpg'
img = load_img(url)
plt.imshow(img)
plt.show()

# %%
img = load_img(url, target_size= (32,32))
plt.imshow(img)

# %%
img = img_to_array(img)
img = img.reshape(1,32*32*3)
img = img.astype('float32')/255

import numpy as np
np.argmax(model100.predict(img), axis = 1)
# Out:
# 1/1 [==============================] - 3s 3s/step
# array([38])

# %%
from matplotlib.image import imread
folder = '/content/drive/MyDrive/AI/My_photo/'
for i in range(60):
  plt.subplot(6,10,i+1)
  filename = folder + 'Hieu' + ' ' + str(i+1) + '.jpg'
  img = imread(filename)
  plt.imshow(img)
plt.show()
