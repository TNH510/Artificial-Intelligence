# %% [markdown]
# <a href="https://colab.research.google.com/github/TNH510/Artificial-Intelligence/blob/main/Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'Housing.csv'
data = pd.read_csv(url)

# %%
import matplotlib.pyplot as plt
data.hist() #So lan lap lai cua data
plt.show()

# %%
#Moi lien quan giua cac dai luong
correlation = data.corr()
print(correlation)
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot = True)
#Gia tri tuyet doi cang lon, moi lien quan cang lon
#Dau tru la nghich bien, dau cong la dong bien
# Out:
# <AxesSubplot:>

# %%
#Ta thấy rằng giá nhà ở phụ thuộc lớn nhất vào diện tích của căn nhà

# %%
data.plot(kind= 'scatter', x = 'area', y = 'price', figsize = (6 , 6), color = 'blue')
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['area']), y= data['price'])
print(model.intercept_)
print(model.coef_)
#y = coef*x + intercept
# Out:
# 2387308.48239643
# [461.97489427]

# %%
#Do chinh xac
model.score(X = pd.DataFrame(data['area']), y= data['price'])
# Out:
# 0.2872931546811469

# %%
data.plot(kind= 'scatter', x = 'area', y= 'price', figsize = (5,5), color = 'red')
y_pred = model.predict(X = pd.DataFrame(data['area']))
plt.plot(data['area'], y_pred, color = 'blue')

# %%
#Mo hinh bac 2
model = linear_model.LinearRegression()
X = pd.DataFrame([data['area'], data['area']**2]).T
model.fit(X, y= data['price'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['price']))

#Ve do thi mo hinh bac 2
import numpy as np
range = np.arange(2000,16000,10)
data.plot(kind= 'scatter', x = 'area', y= 'price', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['price']))
# Out:
# Intercept cua mo hinh: 795440.7576065883
# Coefficient cua mo hinh [ 1.03518489e+03 -4.35645185e-02]
# Do chinh xac cua mo hinh 0.3230746205562587
# Do chinh xac cua model 0.3230746205562587
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mo hinh bac 3
model = linear_model.LinearRegression()
X = pd.DataFrame([data['area'], data['area']**2, data['area']**3]).T
model.fit(X, y= data['price'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['price']))

#Ve do thi mo hinh bac 3
import numpy as np
range = np.arange(2000,16000,10)
data.plot(kind= 'scatter', x = 'area', y= 'price', figsize = (8,8), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['price']))
# Out:
# Intercept cua mo hinh: 23332.878579673357
# Coefficient cua mo hinh [ 1.43801242e+03 -1.03624409e-01  2.57269135e-06]
# Do chinh xac cua mo hinh 0.32504534381488304
# Do chinh xac cua model 0.32504534381488304
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mo hinh bac 4
model = linear_model.LinearRegression()
X = pd.DataFrame([data['area'], data['area']**2, data['area']**3, data['area']**4]).T
model.fit(X, y= data['price'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['price']))
#Ve do thi mo hinh bac 4
import numpy as np
range = np.arange(2000,16000,10)
data.plot(kind= 'scatter', x = 'area', y= 'price', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['price']))
# Out:
# Intercept cua mo hinh: 4765060.861442321
# Coefficient cua mo hinh [-1.87292314e+03  6.60296224e-01 -6.69919196e-05  2.12779050e-09]
# Do chinh xac cua mo hinh 0.34560934200576077
# Do chinh xac cua model 0.34560934200576077
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Mo hinh bac 5
model = linear_model.LinearRegression()
X = pd.DataFrame([data['area'], data['area']**2, data['area']**3, data['area']**4, data['area']**5]).T
model.fit(X, y= data['price'])
print('Intercept cua mo hinh:', model.intercept_)
print('Coefficient cua mo hinh', model.coef_)
print('Do chinh xac cua mo hinh', model.score(X, y = data['price']))
#Ve do thi mo hinh bac 5
import numpy as np
range = np.arange(2000,16000,10)
data.plot(kind= 'scatter', x = 'area', y= 'price', figsize = (5,5), color = 'red')
predictor = pd.DataFrame([range, range**2, range**3, range**4, range**4]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred, color = 'green')
print('Do chinh xac cua model', model.score(X, y = data['price']))
# Out:
# Intercept cua mo hinh: 1920055.940331982
# Coefficient cua mo hinh [ 5.46248556e-05  2.51920230e-01 -3.16670710e-05  1.09290622e-09
#   4.49640325e-15]
# Do chinh xac cua mo hinh 0.3400861683717811
# Do chinh xac cua model 0.3400861683717811
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#Vậy ta thấy mô hình bậc 4 là mô hình có tỉ lệ chính xác nhất
